# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, log_loss
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTENC
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from mlxtend.classifier import StackingClassifier
from sklearn.ensemble import RandomForestClassifier

from category_encoders import TargetEncoder
import category_encoders as ce

from sklearn import model_selection

from DFOneHot import DataFrameOneHotEncoder

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import FeatureUnion, Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder

from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
# %%time
# train_values = pd.read_csv("train_values.csv", dtype ={'geo_level_1_id': str, 'geo_level_2_id': str, 'geo_level_3_id': str})
# train_labels = pd.read_csv("train_labels.csv")
# test_values = pd.read_csv("test_values.csv", dtype ={'geo_level_1_id': str, 'geo_level_2_id': str, 'geo_level_3_id': str})

train_values = pd.read_csv("train_values.csv")
train_labels = pd.read_csv("train_labels.csv")
test_values = pd.read_csv("test_values.csv")
# Out:
# Wall time: 663 ms

# %%
# find number of rows and columns
print(
f'train_values shape: {train_values.shape}\n\
train_labels shape: {train_labels.shape}\n\
test_values shape: {test_values.shape}')
# Out:
# train_values shape: (260601, 39)
# train_labels shape: (260601, 2)
# test_values shape: (86868, 39)

# %%
test_values.shape
# Out:
# (86868, 39)

# %%
def target_encode_multiclass(X,y,cols): #X,y are pandas df and series, cols is a list of column variables
    y=y.astype(str)   #convert to string to onehot encode
    enc=ce.OneHotEncoder().fit(y)
    y_onehot=enc.transform(y)
    class_names=y_onehot.columns  #names of onehot encoded columns
#     X_obj=X.select_dtypes('object') #separate categorical columns
    X_col=X[cols].copy()
    for c in cols:
        X_col[c] = X_col[c].astype(str)
    X_rem=X[[x for x in X.columns if x not in cols]].copy() # remaining columns
    for class_ in class_names:
      
        enc=ce.TargetEncoder(smoothing=0.001)
        enc.fit(X_col,y_onehot[class_]) #convert all categorical 
        temp=enc.transform(X_col)       #columns for class_
        temp.columns=[str(x)+'_'+str(class_) for x in temp.columns]
        X_rem=pd.concat([X_rem,temp],axis=1)    #add to original dataset
    X_rem = pd.concat([X_rem, X[cols]], axis=1)  
    return X_rem

# %%
# possible values and distributions of the label
train_labels.damage_grade.value_counts()
# Out:
# 2    148259
# 3     87218
# 1     25124
# Name: damage_grade, dtype: int64

# %%
train_values.head(2)
# Out:
#    building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0       802906               6             487           12198
# 1        28830               8             900            2812
#
#    count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                    2   30                6                  5
# 1                    2   10                8                  7
#
#   land_surface_condition foundation_type  ... has_secondary_use_agriculture  \
# 0                      t               r  ...                             0
# 1                      o               r  ...                             0
#
#   has_secondary_use_hotel has_secondary_use_rental  \
# 0                       0                        0
# 1                       0                        0
#
#   has_secondary_use_institution has_secondary_use_school  \
# 0                             0                        0
# 1                             0                        0
#
#    has_secondary_use_industry  has_secondary_use_health_post  \
# 0                           0                              0
# 1                           0                              0
#
#    has_secondary_use_gov_office  has_secondary_use_use_police  \
# 0                             0                             0
# 1                             0                             0
#
#    has_secondary_use_other
# 0                        0
# 1                        0
#
# [2 rows x 39 columns]

# %% [markdown]
# # Splitting the Data

# %%
cols_to_drop = ['building_id']

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_values.drop(columns=cols_to_drop), train_labels['damage_grade'], test_size=0.2, random_state=42)

type(X_train)
type(y_train)
# Out:
# pandas.core.series.Series

# %%
X_train = target_encode_multiclass(X_train, y_train, ['geo_level_1_id', 'geo_level_2_id','geo_level_3_id'])

# %%
# %%time
for col in ['geo_level_1_id', 'geo_level_2_id','geo_level_3_id']:
    uniq_v = X_test[col].unique()
    for v1 in uniq_v:
        for v2 in [1,2,3]:
            if v1 in X_train[col].unique():
                X_test.loc[X_test[col]==v1, f'{col}_damage_grade_{v2}'] = \
                    X_train.loc[(X_train[col]==v1),f'{col}_damage_grade_{v2}'].values[0]
            else:
                X_test.loc[X_test[col]==v1, f'{col}_damage_grade_{v2}'] = 0
# Out:
# Wall time: 2min 19s

# %%
categ_col = []
for col in X_train.columns:
    if X_train[col].dtypes not in ('int64', 'float64'):
        categ_col.append(col)
#         print(train_values[col].value_counts(),'\n')
categ_col
# Out:
# ['land_surface_condition',
#  'foundation_type',
#  'roof_type',
#  'ground_floor_type',
#  'other_floor_type',
#  'position',
#  'plan_configuration',
#  'legal_ownership_status']

# %%
transformer = ColumnTransformer(transformers=[('cat', DataFrameOneHotEncoder(handle_unknown='ignore'), categ_col)], 
                                remainder='passthrough')

# %% [markdown]
# # Random Forest

# %%
# %%time
pipe = Pipeline(steps=[("preprocessing", transformer),
                       ('rf', RandomForestClassifier())],
               verbose=True)

param_grid = {
    'rf__n_estimators': [500, 1000], 
    'rf__min_samples_split':[20, 50, 500]
}

search = model_selection.GridSearchCV(pipe, param_grid, cv=3, n_jobs=-1, scoring='f1_micro', return_train_score=True, verbose=2)

search = search.fit(X_train, y_train)
# print(df_ohe.fit_transform(train_values.head(3)))
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [Pipeline] ................ (step 2 of 2) Processing rf, total= 5.3min
# Wall time: 19min 7s

# %%
search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('rf',
#                  RandomForestClassifier(min_samples_split=50,
#                                         n_estimators=1000))],
#          verbose=True)

# %%
def perf(model, X_train, y_train, X_test, y_test):
    y_train_pred = model.predict(X_train)
    train_f1 = f1_score(y_train, y_train_pred, average='micro')
    
    
    y_pred = model.predict(X_test)
#     print(y_pred)
#     predictions = [round(value) for value in y_pred]
    predictions = y_pred
    class_names = [str(x) for x in model.classes_]
    print(classification_report(y_test, y_pred, target_names=class_names))
    accuracy = accuracy_score(y_test, predictions)
#     print("testing Accuracy: %.2f%%" % (accuracy * 100.0))
    print(f'training f1 score: {train_f1}')
    print("testing f1 score = {:.4f}".format(f1_score(y_test, predictions, average='micro')))

# %%
perf(search, X_train, y_train, X_test, y_test)
# Out:
# training f1 score: 0.8004748656945511
#               precision    recall  f1-score   support
#
#            1       0.69      0.52      0.59      5170
#            2       0.74      0.85      0.79     29487
#            3       0.76      0.64      0.69     17464
#
#     accuracy                           0.74     52121
#    macro avg       0.73      0.67      0.69     52121
# weighted avg       0.74      0.74      0.74     52121
#
# testing f1 score = 0.7449

# %% [markdown]
# # Catboost

# %%
# %%time
pipe = Pipeline(steps=[("preprocessing", transformer),
                       ('catboost', CatBoostClassifier())],
               verbose=True)

pipe.fit(X_train, y_train)
# Out:
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# Learning rate set to 0.103895
# 0:	learn: 1.0081407	total: 176ms	remaining: 2m 55s
# 1:	learn: 0.9379490	total: 221ms	remaining: 1m 50s
# 2:	learn: 0.8822975	total: 264ms	remaining: 1m 27s
# 3:	learn: 0.8364730	total: 310ms	remaining: 1m 17s
# 4:	learn: 0.7986968	total: 357ms	remaining: 1m 10s
# 5:	learn: 0.7665293	total: 403ms	remaining: 1m 6s
# 6:	learn: 0.7392604	total: 451ms	remaining: 1m 3s
# 7:	learn: 0.7151789	total: 498ms	remaining: 1m 1s
# 8:	learn: 0.6948902	total: 540ms	remaining: 59.5s
# 9:	learn: 0.6776522	total: 589ms	remaining: 58.3s
# 10:	learn: 0.6623015	total: 655ms	remaining: 58.9s
# 11:	learn: 0.6491421	total: 721ms	remaining: 59.4s
# 12:	learn: 0.6370226	total: 766ms	remaining: 58.2s
# 13:	learn: 0.6265959	total: 831ms	remaining: 58.6s
# 14:	learn: 0.6172473	total: 879ms	remaining: 57.7s
# 15:	learn: 0.6085729	total: 926ms	remaining: 56.9s
# 16:	learn: 0.6021166	total: 969ms	remaining: 56s
# 17:	learn: 0.5950582	total: 1.02s	remaining: 55.7s
# 18:	learn: 0.5890738	total: 1.06s	remaining: 54.9s
# 19:	learn: 0.5832393	total: 1.11s	remaining: 54.2s
# 20:	learn: 0.5786578	total: 1.15s	remaining: 53.8s
# 21:	learn: 0.5743524	total: 1.2s	remaining: 53.5s
# 22:	learn: 0.5702732	total: 1.25s	remaining: 53.2s
# 23:	learn: 0.5665715	total: 1.3s	remaining: 52.8s
# 24:	learn: 0.5628834	total: 1.34s	remaining: 52.2s
# 25:	learn: 0.5600455	total: 1.39s	remaining: 52.1s
# 26:	learn: 0.5576561	total: 1.43s	remaining: 51.5s
# 27:	learn: 0.5553640	total: 1.47s	remaining: 51s
# 28:	learn: 0.5530180	total: 1.51s	remaining: 50.6s
# 29:	learn: 0.5508146	total: 1.58s	remaining: 51.3s
# 30:	learn: 0.5489360	total: 1.62s	remaining: 50.7s
# 31:	learn: 0.5472250	total: 1.67s	remaining: 50.5s
# 32:	learn: 0.5452402	total: 1.71s	remaining: 50.1s
# 33:	learn: 0.5435120	total: 1.75s	remaining: 49.8s
# 34:	learn: 0.5426111	total: 1.79s	remaining: 49.4s
# 35:	learn: 0.5410399	total: 1.84s	remaining: 49.3s
# 36:	learn: 0.5396352	total: 1.89s	remaining: 49.1s
# 37:	learn: 0.5382730	total: 1.93s	remaining: 49s
# 38:	learn: 0.5373512	total: 1.98s	remaining: 48.7s
# 39:	learn: 0.5367488	total: 2.04s	remaining: 48.8s
# 40:	learn: 0.5361430	total: 2.08s	remaining: 48.6s
# 41:	learn: 0.5355402	total: 2.12s	remaining: 48.3s
# 42:	learn: 0.5345820	total: 2.2s	remaining: 49s
# 43:	learn: 0.5337396	total: 2.25s	remaining: 48.8s
# 44:	learn: 0.5327193	total: 2.3s	remaining: 48.7s
# 45:	learn: 0.5322696	total: 2.34s	remaining: 48.5s
# 46:	learn: 0.5314869	total: 2.41s	remaining: 48.8s
# 47:	learn: 0.5310106	total: 2.45s	remaining: 48.5s
# 94:	learn: 0.5185588	total: 4.71s	remaining: 44.9s
# 95:	learn: 0.5183639	total: 4.78s	remaining: 45s
# 96:	learn: 0.5182188	total: 4.82s	remaining: 44.9s
# 97:	learn: 0.5180709	total: 4.89s	remaining: 45s
# 98:	learn: 0.5178328	total: 4.93s	remaining: 44.9s
# 99:	learn: 0.5177121	total: 4.98s	remaining: 44.8s
# 100:	learn: 0.5174972	total: 5.03s	remaining: 44.7s
# 101:	learn: 0.5173847	total: 5.07s	remaining: 44.6s
# 102:	learn: 0.5172662	total: 5.11s	remaining: 44.5s
# 103:	learn: 0.5171932	total: 5.16s	remaining: 44.5s
# 104:	learn: 0.5171216	total: 5.22s	remaining: 44.5s
# 105:	learn: 0.5169477	total: 5.26s	remaining: 44.4s
# 106:	learn: 0.5168036	total: 5.3s	remaining: 44.3s
# 107:	learn: 0.5167363	total: 5.35s	remaining: 44.2s
# 108:	learn: 0.5166206	total: 5.39s	remaining: 44.1s
# 109:	learn: 0.5165367	total: 5.43s	remaining: 44s
# 110:	learn: 0.5164175	total: 5.48s	remaining: 43.9s
# 111:	learn: 0.5162404	total: 5.53s	remaining: 43.9s
# 112:	learn: 0.5161281	total: 5.57s	remaining: 43.8s
# 113:	learn: 0.5160379	total: 5.62s	remaining: 43.6s
# 114:	learn: 0.5159469	total: 5.67s	remaining: 43.6s
# 115:	learn: 0.5158580	total: 5.71s	remaining: 43.5s
# 116:	learn: 0.5156552	total: 5.74s	remaining: 43.3s
# 117:	learn: 0.5155787	total: 5.79s	remaining: 43.3s
# 118:	learn: 0.5155154	total: 5.83s	remaining: 43.2s
# 119:	learn: 0.5154561	total: 5.88s	remaining: 43.1s
# 120:	learn: 0.5152664	total: 5.92s	remaining: 43s
# 121:	learn: 0.5152079	total: 5.96s	remaining: 42.9s
# 122:	learn: 0.5150257	total: 5.99s	remaining: 42.7s
# 123:	learn: 0.5148964	total: 6.04s	remaining: 42.7s
# 124:	learn: 0.5147762	total: 6.09s	remaining: 42.6s
# 125:	learn: 0.5146819	total: 6.13s	remaining: 42.5s
# 126:	learn: 0.5145796	total: 6.19s	remaining: 42.6s
# 127:	learn: 0.5144392	total: 6.25s	remaining: 42.6s
# 128:	learn: 0.5143076	total: 6.29s	remaining: 42.5s
# 129:	learn: 0.5141937	total: 6.34s	remaining: 42.4s
# 130:	learn: 0.5141418	total: 6.39s	remaining: 42.4s
# 131:	learn: 0.5140720	total: 6.43s	remaining: 42.3s
# 132:	learn: 0.5139109	total: 6.49s	remaining: 42.3s
# 133:	learn: 0.5138085	total: 6.55s	remaining: 42.3s
# 134:	learn: 0.5137314	total: 6.6s	remaining: 42.3s
# 135:	learn: 0.5135814	total: 6.66s	remaining: 42.3s
# 136:	learn: 0.5135145	total: 6.71s	remaining: 42.3s
# 137:	learn: 0.5134103	total: 6.77s	remaining: 42.3s
# 138:	learn: 0.5133305	total: 6.82s	remaining: 42.2s
# 139:	learn: 0.5131819	total: 6.87s	remaining: 42.2s
# 140:	learn: 0.5130953	total: 6.93s	remaining: 42.2s
# 141:	learn: 0.5129408	total: 6.98s	remaining: 42.2s
# 142:	learn: 0.5128512	total: 7.03s	remaining: 42.1s
# 143:	learn: 0.5127587	total: 7.07s	remaining: 42s
# 144:	learn: 0.5126525	total: 7.12s	remaining: 42s
# 145:	learn: 0.5125429	total: 7.18s	remaining: 42s
# 146:	learn: 0.5124619	total: 7.24s	remaining: 42s
# 147:	learn: 0.5123456	total: 7.28s	remaining: 41.9s
# 148:	learn: 0.5122597	total: 7.32s	remaining: 41.8s
# 149:	learn: 0.5121849	total: 7.37s	remaining: 41.7s
# 150:	learn: 0.5121061	total: 7.43s	remaining: 41.8s
# 151:	learn: 0.5119648	total: 7.48s	remaining: 41.7s
# 152:	learn: 0.5119148	total: 7.52s	remaining: 41.7s
# 153:	learn: 0.5118561	total: 7.59s	remaining: 41.7s
# 154:	learn: 0.5117242	total: 7.65s	remaining: 41.7s
# 155:	learn: 0.5116901	total: 7.7s	remaining: 41.7s
# 156:	learn: 0.5116186	total: 7.74s	remaining: 41.6s
# 157:	learn: 0.5115232	total: 7.79s	remaining: 41.5s
# 158:	learn: 0.5114578	total: 7.83s	remaining: 41.4s
# 159:	learn: 0.5113622	total: 7.89s	remaining: 41.4s
# 160:	learn: 0.5112942	total: 7.93s	remaining: 41.3s
# 161:	learn: 0.5111988	total: 8s	remaining: 41.4s
# 162:	learn: 0.5110965	total: 8.05s	remaining: 41.3s
# 163:	learn: 0.5110270	total: 8.1s	remaining: 41.3s
# 164:	learn: 0.5109716	total: 8.14s	remaining: 41.2s
# 165:	learn: 0.5109103	total: 8.18s	remaining: 41.1s
# 166:	learn: 0.5108853	total: 8.23s	remaining: 41s
# 167:	learn: 0.5108015	total: 8.28s	remaining: 41s
# 168:	learn: 0.5107395	total: 8.32s	remaining: 40.9s
# 169:	learn: 0.5106929	total: 8.38s	remaining: 40.9s
# 170:	learn: 0.5106276	total: 8.41s	remaining: 40.8s
# 171:	learn: 0.5105615	total: 8.45s	remaining: 40.7s
# 172:	learn: 0.5105262	total: 8.49s	remaining: 40.6s
# 173:	learn: 0.5104504	total: 8.53s	remaining: 40.5s
# 174:	learn: 0.5103925	total: 8.57s	remaining: 40.4s
# 175:	learn: 0.5103215	total: 8.63s	remaining: 40.4s
# 176:	learn: 0.5101755	total: 8.68s	remaining: 40.4s
# 177:	learn: 0.5101353	total: 8.73s	remaining: 40.3s
# 178:	learn: 0.5100655	total: 8.78s	remaining: 40.3s
# 179:	learn: 0.5100218	total: 8.82s	remaining: 40.2s
# 180:	learn: 0.5099789	total: 8.88s	remaining: 40.2s
# 181:	learn: 0.5099326	total: 8.92s	remaining: 40.1s
# 182:	learn: 0.5098672	total: 8.97s	remaining: 40s
# 183:	learn: 0.5098139	total: 9.01s	remaining: 40s
# 184:	learn: 0.5097641	total: 9.06s	remaining: 39.9s
# 185:	learn: 0.5096797	total: 9.12s	remaining: 39.9s
# 186:	learn: 0.5096141	total: 9.17s	remaining: 39.9s
# 327:	learn: 0.5019041	total: 15.8s	remaining: 32.4s
# 328:	learn: 0.5018790	total: 15.9s	remaining: 32.4s
# 329:	learn: 0.5018341	total: 16s	remaining: 32.4s
# 330:	learn: 0.5017901	total: 16s	remaining: 32.4s
# 331:	learn: 0.5017503	total: 16.1s	remaining: 32.3s
# 332:	learn: 0.5016963	total: 16.1s	remaining: 32.3s
# 333:	learn: 0.5016645	total: 16.2s	remaining: 32.2s
# 334:	learn: 0.5016264	total: 16.2s	remaining: 32.2s
# 335:	learn: 0.5015946	total: 16.3s	remaining: 32.1s
# 336:	learn: 0.5015484	total: 16.3s	remaining: 32.1s
# 337:	learn: 0.5015149	total: 16.4s	remaining: 32s
# 338:	learn: 0.5014831	total: 16.4s	remaining: 32s
# 339:	learn: 0.5014436	total: 16.4s	remaining: 31.9s
# 340:	learn: 0.5014023	total: 16.5s	remaining: 31.9s
# 341:	learn: 0.5013596	total: 16.6s	remaining: 31.9s
# 342:	learn: 0.5013266	total: 16.6s	remaining: 31.8s
# 343:	learn: 0.5013084	total: 16.7s	remaining: 31.8s
# 344:	learn: 0.5012397	total: 16.7s	remaining: 31.7s
# 345:	learn: 0.5012034	total: 16.8s	remaining: 31.7s
# 346:	learn: 0.5011495	total: 16.8s	remaining: 31.6s
# 347:	learn: 0.5011099	total: 16.9s	remaining: 31.6s
# 348:	learn: 0.5010675	total: 16.9s	remaining: 31.6s
# 349:	learn: 0.5010124	total: 17s	remaining: 31.5s
# 350:	learn: 0.5009679	total: 17s	remaining: 31.4s
# 351:	learn: 0.5009360	total: 17.1s	remaining: 31.4s
# 352:	learn: 0.5009096	total: 17.1s	remaining: 31.4s
# 353:	learn: 0.5008683	total: 17.2s	remaining: 31.3s
# 354:	learn: 0.5008203	total: 17.2s	remaining: 31.3s
# 355:	learn: 0.5007714	total: 17.2s	remaining: 31.2s
# 356:	learn: 0.5007180	total: 17.3s	remaining: 31.1s
# 357:	learn: 0.5006821	total: 17.3s	remaining: 31.1s
# 358:	learn: 0.5006531	total: 17.4s	remaining: 31s
# 359:	learn: 0.5005938	total: 17.4s	remaining: 31s
# 360:	learn: 0.5005434	total: 17.5s	remaining: 30.9s
# 361:	learn: 0.5005263	total: 17.5s	remaining: 30.9s
# 362:	learn: 0.5004763	total: 17.6s	remaining: 30.8s
# 363:	learn: 0.5004436	total: 17.6s	remaining: 30.7s
# 364:	learn: 0.5003835	total: 17.6s	remaining: 30.7s
# 365:	learn: 0.5003265	total: 17.7s	remaining: 30.6s
# 366:	learn: 0.5002813	total: 17.7s	remaining: 30.6s
# 367:	learn: 0.5002366	total: 17.8s	remaining: 30.6s
# 368:	learn: 0.5002184	total: 17.8s	remaining: 30.5s
# 369:	learn: 0.5001806	total: 17.9s	remaining: 30.4s
# 370:	learn: 0.5001401	total: 17.9s	remaining: 30.4s
# 371:	learn: 0.5000922	total: 18s	remaining: 30.3s
# 372:	learn: 0.5000707	total: 18s	remaining: 30.3s
# 653:	learn: 0.4905671	total: 31.5s	remaining: 16.6s
# 654:	learn: 0.4905298	total: 31.5s	remaining: 16.6s
# 655:	learn: 0.4905071	total: 31.6s	remaining: 16.6s
# 656:	learn: 0.4904776	total: 31.6s	remaining: 16.5s
# 657:	learn: 0.4904628	total: 31.7s	remaining: 16.5s
# 658:	learn: 0.4904330	total: 31.7s	remaining: 16.4s
# 659:	learn: 0.4903944	total: 31.7s	remaining: 16.3s
# 660:	learn: 0.4903406	total: 31.8s	remaining: 16.3s
# 661:	learn: 0.4903015	total: 31.8s	remaining: 16.2s
# 662:	learn: 0.4902819	total: 31.9s	remaining: 16.2s
# 663:	learn: 0.4902415	total: 31.9s	remaining: 16.2s
# 664:	learn: 0.4902207	total: 32s	remaining: 16.1s
# 665:	learn: 0.4901975	total: 32s	remaining: 16.1s
# 666:	learn: 0.4901707	total: 32.1s	remaining: 16s
# 667:	learn: 0.4901572	total: 32.1s	remaining: 16s
# 668:	learn: 0.4901303	total: 32.2s	remaining: 15.9s
# 669:	learn: 0.4901175	total: 32.2s	remaining: 15.9s
# 670:	learn: 0.4900919	total: 32.3s	remaining: 15.8s
# 671:	learn: 0.4900605	total: 32.3s	remaining: 15.8s
# 672:	learn: 0.4900345	total: 32.3s	remaining: 15.7s
# 673:	learn: 0.4900152	total: 32.4s	remaining: 15.7s
# 674:	learn: 0.4899947	total: 32.4s	remaining: 15.6s
# 675:	learn: 0.4899633	total: 32.5s	remaining: 15.6s
# 676:	learn: 0.4899391	total: 32.5s	remaining: 15.5s
# 677:	learn: 0.4899087	total: 32.6s	remaining: 15.5s
# 678:	learn: 0.4898860	total: 32.6s	remaining: 15.4s
# 679:	learn: 0.4898580	total: 32.7s	remaining: 15.4s
# 680:	learn: 0.4898215	total: 32.7s	remaining: 15.3s
# 681:	learn: 0.4897900	total: 32.8s	remaining: 15.3s
# 682:	learn: 0.4897593	total: 32.9s	remaining: 15.2s
# 683:	learn: 0.4897336	total: 32.9s	remaining: 15.2s
# 684:	learn: 0.4896959	total: 33s	remaining: 15.2s
# 685:	learn: 0.4896757	total: 33s	remaining: 15.1s
# 686:	learn: 0.4896551	total: 33.1s	remaining: 15.1s
# 687:	learn: 0.4896283	total: 33.1s	remaining: 15s
# 688:	learn: 0.4895939	total: 33.2s	remaining: 15s
# 689:	learn: 0.4895671	total: 33.2s	remaining: 14.9s
# 690:	learn: 0.4895488	total: 33.2s	remaining: 14.9s
# 691:	learn: 0.4895207	total: 33.3s	remaining: 14.8s
# 692:	learn: 0.4894920	total: 33.3s	remaining: 14.8s
# 693:	learn: 0.4894687	total: 33.4s	remaining: 14.7s
# 694:	learn: 0.4894378	total: 33.4s	remaining: 14.7s
# 695:	learn: 0.4894192	total: 33.5s	remaining: 14.6s
# 696:	learn: 0.4893814	total: 33.5s	remaining: 14.6s
# 697:	learn: 0.4893337	total: 33.6s	remaining: 14.5s
# 698:	learn: 0.4892946	total: 33.6s	remaining: 14.5s
# 978:	learn: 0.4818168	total: 46.9s	remaining: 1s
# 979:	learn: 0.4817914	total: 46.9s	remaining: 957ms
# 980:	learn: 0.4817694	total: 47s	remaining: 910ms
# 981:	learn: 0.4817563	total: 47s	remaining: 862ms
# 982:	learn: 0.4817328	total: 47.1s	remaining: 814ms
# 983:	learn: 0.4817007	total: 47.1s	remaining: 766ms
# 984:	learn: 0.4816781	total: 47.2s	remaining: 718ms
# 985:	learn: 0.4816572	total: 47.2s	remaining: 670ms
# 986:	learn: 0.4816229	total: 47.2s	remaining: 622ms
# 987:	learn: 0.4816069	total: 47.3s	remaining: 574ms
# 988:	learn: 0.4815798	total: 47.3s	remaining: 526ms
# 989:	learn: 0.4815668	total: 47.4s	remaining: 479ms
# 990:	learn: 0.4815350	total: 47.4s	remaining: 431ms
# 991:	learn: 0.4815150	total: 47.5s	remaining: 383ms
# 992:	learn: 0.4814977	total: 47.5s	remaining: 335ms
# 993:	learn: 0.4814700	total: 47.6s	remaining: 287ms
# 994:	learn: 0.4814508	total: 47.6s	remaining: 239ms
# 995:	learn: 0.4814235	total: 47.6s	remaining: 191ms
# 996:	learn: 0.4813942	total: 47.7s	remaining: 144ms
# 997:	learn: 0.4813560	total: 47.7s	remaining: 95.7ms
# 998:	learn: 0.4813248	total: 47.8s	remaining: 47.8ms
# 999:	learn: 0.4813105	total: 47.8s	remaining: 0us
# [Pipeline] .......... (step 2 of 2) Processing catboost, total=  48.9s
# Wall time: 49.4 s
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('catboost',
#                  <catboost.core.CatBoostClassifier object at 0x0000024ABA569E48>)],
#          verbose=True)

# %%
perf(pipe, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.54      0.60      5170
#            2       0.75      0.84      0.79     29487
#            3       0.75      0.64      0.69     17464
#
#     accuracy                           0.74     52121
#    macro avg       0.73      0.67      0.70     52121
# weighted avg       0.74      0.74      0.74     52121
#
# training f1 score: 0.7799932847275519
# testing f1 score = 0.7430

# %% [markdown]
# # LGBM

# %%
# %%time
pipe = Pipeline(steps=[("preprocessing", transformer),
                       ('lgbm', LGBMClassifier())],
               verbose=True)
param_grid = {

        'lgbm__bagging_fraction': (0.5, 0.8),
        'lgbm__bagging_frequency': (5, 8),

        'lgbm__feature_fraction': (0.5, 1),
        'lgbm__max_depth': (10, 13),
        'lgbm__n_estimators': (100, 1000),
        'lgbm__learning_rate': (0.01, 0.3),
        'lgbm__min_data_in_leaf': (90, 120),
        'lgbm__num_leaves': (1200, 1550)

}

search = model_selection.RandomizedSearchCV(pipe, param_grid, cv=3, n_jobs=-1, scoring='f1_micro', 
                                            return_train_score=False, verbose=2, random_state=1, n_iter=20)

search = search.fit(X_train, y_train)

# pipe.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [LightGBM] [Warning] Unknown parameter: bagging_frequency
# [LightGBM] [Warning] feature_fraction is set=1, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=1
# [LightGBM] [Warning] min_data_in_leaf is set=90, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=90
# [LightGBM] [Warning] bagging_fraction is set=0.5, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5
# [Pipeline] .............. (step 2 of 2) Processing lgbm, total= 1.8min
# Wall time: 28min

# %%
perf(search, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.68      0.55      0.61      5170
#            2       0.75      0.84      0.79     29487
#            3       0.75      0.64      0.69     17464
#
#     accuracy                           0.74     52121
#    macro avg       0.73      0.68      0.70     52121
# weighted avg       0.74      0.74      0.74     52121
#
# training f1 score: 0.7873656945510361
# testing f1 score = 0.7429

# %%
perf(pipe, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.54      0.60      5170
#            2       0.74      0.84      0.79     29487
#            3       0.75      0.64      0.69     17464
#
#     accuracy                           0.74     52121
#    macro avg       0.72      0.67      0.69     52121
# weighted avg       0.74      0.74      0.74     52121
#
# training f1 score: 0.7700211051419801
# testing f1 score = 0.7396

# %% [markdown]
# # FLAML

# %%
from flaml import AutoML
automl = AutoML()
automl_settings = {
    "flaml__time_budget": 300,  # in seconds
    "flaml__metric": 'micro_f1',
    "flaml__eval_method": 'cv',
    "flaml__n_splits": 3,
    "flaml__task": 'classification',
    "flaml__log_file_name": "EQ.log",
    "flaml__n_jobs": -1
}

# %%
# %%time
pipe = Pipeline(steps=[("preprocessing", transformer),
                       ('flaml', automl)],
               verbose=True)

pipe.fit(X_train, y_train, **automl_settings)
# Out:
# [flaml.automl: 12-12 14:08:14] {1926} INFO - task = classification
# [flaml.automl: 12-12 14:08:14] {1928} INFO - Data split method: stratified
# [flaml.automl: 12-12 14:08:14] {1932} INFO - Evaluation method: cv
# [flaml.automl: 12-12 14:08:14] {1999} INFO - Minimizing error metric: 1-micro_f1
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [flaml.automl: 12-12 14:08:14] {2051} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl: 12-12 14:08:15] {2291} INFO - iteration 0, current learner lgbm
# [flaml.automl: 12-12 14:08:16] {2405} INFO - Estimated sufficient time budget=11274s. Estimated necessary time budget=277s.
# [flaml.automl: 12-12 14:08:16] {2485} INFO -  at 1.6s,	estimator lgbm's best error=0.3030,	best estimator lgbm's best error=0.3030
# [flaml.automl: 12-12 14:08:16] {2291} INFO - iteration 1, current learner lgbm
# [flaml.automl: 12-12 14:08:17] {2485} INFO -  at 2.7s,	estimator lgbm's best error=0.3030,	best estimator lgbm's best error=0.3030
# [flaml.automl: 12-12 14:08:17] {2291} INFO - iteration 2, current learner lgbm
# [flaml.automl: 12-12 14:08:18] {2485} INFO -  at 3.8s,	estimator lgbm's best error=0.2586,	best estimator lgbm's best error=0.2586
# [flaml.automl: 12-12 14:08:18] {2291} INFO - iteration 3, current learner xgboost
# [flaml.automl: 12-12 14:08:22] {2485} INFO -  at 7.6s,	estimator xgboost's best error=0.2653,	best estimator lgbm's best error=0.2586
# [flaml.automl: 12-12 14:08:22] {2291} INFO - iteration 4, current learner extra_tree
# [flaml.automl: 12-12 14:08:25] {2485} INFO -  at 11.1s,	estimator extra_tree's best error=0.2731,	best estimator lgbm's best error=0.2586
# [flaml.automl: 12-12 14:08:25] {2291} INFO - iteration 5, current learner lgbm
# [flaml.automl: 12-12 14:08:27] {2485} INFO -  at 12.4s,	estimator lgbm's best error=0.2471,	best estimator lgbm's best error=0.2471
# [flaml.automl: 12-12 14:08:27] {2291} INFO - iteration 6, current learner lgbm
# [flaml.automl: 12-12 14:08:28] {2485} INFO -  at 13.4s,	estimator lgbm's best error=0.2471,	best estimator lgbm's best error=0.2471
# [flaml.automl: 12-12 14:08:28] {2291} INFO - iteration 7, current learner lgbm
# [flaml.automl: 12-12 14:08:29] {2485} INFO -  at 14.8s,	estimator lgbm's best error=0.2443,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:29] {2291} INFO - iteration 8, current learner rf
# [flaml.automl: 12-12 14:08:32] {2485} INFO -  at 18.1s,	estimator rf's best error=0.2918,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:32] {2291} INFO - iteration 9, current learner lgbm
# [flaml.automl: 12-12 14:08:34] {2485} INFO -  at 19.4s,	estimator lgbm's best error=0.2443,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:34] {2291} INFO - iteration 10, current learner lgbm
# [flaml.automl: 12-12 14:08:35] {2485} INFO -  at 20.7s,	estimator lgbm's best error=0.2443,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:35] {2291} INFO - iteration 11, current learner rf
# [flaml.automl: 12-12 14:08:39] {2485} INFO -  at 24.9s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:39] {2291} INFO - iteration 12, current learner rf
# [flaml.automl: 12-12 14:08:42] {2485} INFO -  at 28.1s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:42] {2291} INFO - iteration 13, current learner xgboost
# [flaml.automl: 12-12 14:08:46] {2485} INFO -  at 31.5s,	estimator xgboost's best error=0.2651,	best estimator lgbm's best error=0.2443
# [flaml.automl: 12-12 14:08:46] {2291} INFO - iteration 14, current learner lgbm
# [flaml.automl: 12-12 14:08:48] {2485} INFO -  at 33.7s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 12-12 14:08:48] {2291} INFO - iteration 15, current learner extra_tree
# [flaml.automl: 12-12 14:08:54] {2485} INFO -  at 39.6s,	estimator extra_tree's best error=0.2638,	best estimator lgbm's best error=0.2418
# [flaml.automl: 12-12 14:08:54] {2291} INFO - iteration 16, current learner lgbm
# [flaml.automl: 12-12 14:08:55] {2485} INFO -  at 40.9s,	estimator lgbm's best error=0.2418,	best estimator lgbm's best error=0.2418
# [flaml.automl: 12-12 14:08:55] {2291} INFO - iteration 17, current learner rf
# [flaml.automl: 12-12 14:09:00] {2485} INFO -  at 45.9s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2418
# [flaml.automl: 12-12 14:09:00] {2291} INFO - iteration 18, current learner lgbm
# [flaml.automl: 12-12 14:09:07] {2485} INFO -  at 53.0s,	estimator lgbm's best error=0.2385,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:09:07] {2291} INFO - iteration 19, current learner rf
# [flaml.automl: 12-12 14:09:13] {2485} INFO -  at 58.9s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:09:13] {2291} INFO - iteration 20, current learner lgbm
# [flaml.automl: 12-12 14:09:25] {2485} INFO -  at 70.5s,	estimator lgbm's best error=0.2385,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:09:25] {2291} INFO - iteration 21, current learner rf
# [flaml.automl: 12-12 14:09:29] {2485} INFO -  at 74.7s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:09:29] {2291} INFO - iteration 22, current learner lgbm
# [flaml.automl: 12-12 14:09:35] {2485} INFO -  at 81.2s,	estimator lgbm's best error=0.2385,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:09:35] {2291} INFO - iteration 23, current learner catboost
# [flaml.automl: 12-12 14:10:04] {2485} INFO -  at 109.8s,	estimator catboost's best error=0.2388,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:10:04] {2291} INFO - iteration 24, current learner lgbm
# [flaml.automl: 12-12 14:10:11] {2485} INFO -  at 117.2s,	estimator lgbm's best error=0.2385,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:10:11] {2291} INFO - iteration 25, current learner xgboost
# [flaml.automl: 12-12 14:10:15] {2485} INFO -  at 120.5s,	estimator xgboost's best error=0.2651,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:10:15] {2291} INFO - iteration 26, current learner extra_tree
# [flaml.automl: 12-12 14:10:18] {2485} INFO -  at 124.2s,	estimator extra_tree's best error=0.2638,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:10:18] {2291} INFO - iteration 27, current learner rf
# [flaml.automl: 12-12 14:10:23] {2485} INFO -  at 128.6s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:10:23] {2291} INFO - iteration 28, current learner catboost
# [flaml.automl: 12-12 14:13:09] {2485} INFO -  at 295.1s,	estimator catboost's best error=0.2388,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:13:09] {2291} INFO - iteration 29, current learner rf
# [flaml.automl: 12-12 14:13:14] {2485} INFO -  at 299.2s,	estimator rf's best error=0.2546,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:13:14] {2291} INFO - iteration 30, current learner xgb_limitdepth
# [flaml.automl: 12-12 14:13:15] {2485} INFO -  at 300.7s,	estimator xgb_limitdepth's best error=0.2477,	best estimator lgbm's best error=0.2385
# [flaml.automl: 12-12 14:13:18] {2697} INFO - retrain lgbm for 2.8s
# [flaml.automl: 12-12 14:13:18] {2702} INFO - retrained model: LGBMClassifier(colsample_bytree=0.6649148062238498,
#                learning_rate=0.17402065726724145, max_bin=255,
#                min_child_samples=3, n_estimators=189, num_leaves=20,
#                reg_alpha=0.0009765625, reg_lambda=0.006761362450996487,
#                verbose=-1)
# [flaml.automl: 12-12 14:13:18] {2080} INFO - fit succeeded
# [flaml.automl: 12-12 14:13:18] {2082} INFO - Time taken to find the best model: 53.04538369178772
# [Pipeline] ............. (step 2 of 2) Processing flaml, total= 5.1min
# Wall time: 5min 3s
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('flaml',
#                  AutoML(append_log=False, auto_augment=Tru...
#                         log_file_name='', log_training_metric=False,
#                         log_type='better', max_iter=1000000,
#                         mem_thres=4294967296, metric='auto',
#                         min_sample_size=10000, model_history=False,
#                         n_concurrent_trials=1, n_jobs=-1, n_splits=5,
#                         pred_time_limit=inf, retrain_full=True, sample=True,
#                         split_ratio=0.1, split_type='auto', starting_points={},
#                         task='classification', time_budget=60,
#                         train_time_limit=inf, ...))],
#          verbose=True)

# %%
perf(pipe, X_train, y_train, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.54      0.60      5170
#            2       0.75      0.83      0.79     29487
#            3       0.75      0.64      0.69     17464
#
#     accuracy                           0.74     52121
#    macro avg       0.72      0.67      0.69     52121
# weighted avg       0.74      0.74      0.74     52121
#
# training f1 score: 0.7765349194167306
# testing f1 score = 0.7402

# %% [markdown]
# # Stacking

# %%
# %%time

# clf1 = Pipeline(steps=[("preprocessing", transformer),
#                        ('DT', DecisionTreeClassifier(max_depth=4))],
#                verbose=True)
clf1 = make_pipeline(transformer, DecisionTreeClassifier(max_depth=4))
clf1.fit(X_train, y_train)
clf2 = Pipeline(steps=[("preprocessing", transformer),
                       ('KNN', KNeighborsClassifier(n_neighbors=7))],
               verbose=True)
clf2.fit(X_train, y_train)
clf4 = Pipeline(steps=[("preprocessing", transformer),
                       ('rf', RandomForestClassifier(n_estimators=1000, min_samples_split=50, random_state=0))],
               verbose=True)
clf4.fit(X_train, y_train)
clf5 = Pipeline(steps=[("preprocessing", transformer),
                       ('xgb', XGBClassifier(max_depth=8, n_estimators=180, random_state=0))],
               verbose=True)                       
clf5.fit(X_train, y_train)

classifiers=[('DT', clf1), ('KNN', clf2), ('RF', clf4), ('XGB', clf5)]

sclf = StackingClassifier(
    classifiers=[clf1, clf2, clf4], meta_classifier=XGBClassifier(), fit_base_estimators=False,
    use_probas=True, average_probas=False)
pipe = Pipeline([
                 ('classifier', sclf)])

pipe.fit(X_train, y_train)
# Out:
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [Pipeline] ............... (step 2 of 2) Processing KNN, total=   0.0s
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [Pipeline] ................ (step 2 of 2) Processing rf, total= 5.5min
# [Pipeline] ..... (step 1 of 2) Processing preprocessing, total=   0.5s
# [Pipeline] ............... (step 2 of 2) Processing xgb, total= 9.6min
# Wall time: 28min 12s
# Pipeline(steps=[('classifier',
#                  StackingClassifier(classifiers=[Pipeline(steps=[('columntransformer',
#                                                                   ColumnTransformer(remainder='passthrough',
#                                                                                     transformers=[('cat',
#                                                                                                    DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                                                                    ['land_surface_condition',
#                                                                                                     'foundation_type',
#                                                                                                     'roof_type',
#                                                                                                     'ground_floor_type',
#                                                                                                     'other_floor_type',
#                                                                                                     'position',
#                                                                                                     'plan_configuration',
#                                                                                                     'legal_owners...
#                                                                                                     'foundation_type',
#                                                                                                     'roof_type',
#                                                                                                     'ground_floor_type',
#                                                                                                     'other_floor_type',
#                                                                                                     'position',
#                                                                                                     'plan_configuration',
#                                                                                                     'legal_ownership_status'])])),
#                                                                  ('rf',
#                                                                   RandomForestClassifier(min_samples_split=50,
#                                                                                          n_estimators=1000,
#                                                                                          random_state=0))],
#                                                           verbose=True)],
#                                     fit_base_estimators=False,
#                                     meta_classifier=XGBClassifier(objective='multi:softprob'),
#                                     use_clones=False, use_probas=True))])

# %%
for pipe in [clf1, clf2, clf4]:
    print(f'\n-----------------{pipe}---------------\n')
    print(perf(pipe, X_train, y_train, X_test, y_test))
# Out:
# -----------------Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('decisiontreeclassifier',
#                  DecisionTreeClassifier(max_depth=4))])---------------
#
#               precision    recall  f1-score   support
#
#            1       0.63      0.38      0.47      5170
#            2       0.72      0.84      0.78     29487
#            3       0.74      0.62      0.67     17464
#
#     accuracy                           0.72     52121
#    macro avg       0.70      0.61      0.64     52121
# weighted avg       0.72      0.72      0.71     52121
#
# training f1 score: 0.7431504221028394
# testing f1 score = 0.7202
# None
#
# -----------------Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('KNN', KNeighborsClassifier(n_neighbors=7))],
#          verbose=True)---------------
#
#               precision    recall  f1-score   support
#
#            1       0.61      0.47      0.53      5170
#            2       0.73      0.80      0.76     29487
#            3       0.69      0.62      0.65     17464
#
#     accuracy                           0.71     52121
#    macro avg       0.68      0.63      0.65     52121
# weighted avg       0.70      0.71      0.70     52121
#
# training f1 score: 0.7741749808135073
# testing f1 score = 0.7074
# None
#
# -----------------Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   DataFrameOneHotEncoder(handle_unknown='ignore'),
#                                                   ['land_surface_condition',
#                                                    'foundation_type',
#                                                    'roof_type',
#                                                    'ground_floor_type',
#                                                    'other_floor_type',
#                                                    'position',
#                                                    'plan_configuration',
#                                                    'legal_ownership_status'])])),
#                 ('rf',
#                  RandomForestClassifier(min_samples_split=50, n_estimators=1000,
#                                         random_state=0))],
#          verbose=True)---------------
#
#               precision    recall  f1-score   support
#
#            1       0.69      0.52      0.59      5170
#            2       0.74      0.85      0.79     29487
#            3       0.76      0.64      0.70     17464
#
#     accuracy                           0.75     52121
#    macro avg       0.73      0.67      0.69     52121
# weighted avg       0.74      0.75      0.74     52121
#
# training f1 score: 0.8003117805065234
# testing f1 score = 0.7451
# None

# %%
model = pipe
y_train_pred = model.predict(X_train)
train_f1 = f1_score(y_train, y_train_pred, average='micro')

# %%
y_pred = model.predict(X_test)
#     print(y_pred)
#     predictions = [round(value) for value in y_pred]
predictions = y_pred
# class_names = [str(x) for x in model.classes_]
# print(classification_report(y_test, y_pred, target_names=class_names))
accuracy = accuracy_score(y_test, predictions)
#     print("testing Accuracy: %.2f%%" % (accuracy * 100.0))
print(f'training f1 score: {train_f1}')
print("testing f1 score = {:.4f}".format(f1_score(y_test, predictions, average='micro')))
# Out:
# training f1 score: 0.834535686876439
# testing f1 score = 0.7347
